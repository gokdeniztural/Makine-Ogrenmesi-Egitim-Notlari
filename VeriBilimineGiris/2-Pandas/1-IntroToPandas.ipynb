# %%
import numpy as np
import pandas as pd

# %%
grades = {"Gökdeniz": 90 , "James":50, "Adam":75}

# %%
pd.Series(grades)

# %%
names = ["Gökdeniz","James","Adam"]
grades = [90,50,75]

# %%
pd.Series(names)

# %%
pd.Series(grades,names)

# %%
pd.Series(data = grades , index = names)

# %%
# with numpy

# %%
numpy_array = np.array([50,40,30,20])
names_array = ["Gökdeniz","Faruk","Fatih","Kayra"]

# %%
pd.Series(data = numpy_array , index = names_array)

# %%
# Data frameler series'lerin birleşimi !!!

# %% [markdown]
# # arithmetic

# %%
contest_result = pd.Series(data = [10,5,100], index = ["Gökdeniz","Fatih","Kayra"])
contest_result2 = pd.Series(data = [20,50,10], index = ["Gökdeniz","Fatih","Kayra"])

# %%
contest_result

# %%
contest_result["Gökdeniz"]

# %%
contest_result2["Kayra"]

# %%
final_result = contest_result + contest_result2

# %%
final_result

# %%
# Bütün aritmetik işlemleri aynı şekilde yapabilir. İndexler name olduğu için hangi değerleri toplanacağı belli...

# %%
different_series = pd.Series([10,20,30,40],["a","b","c","d"])

# %%
different_series

# %%
different_series2 = pd.Series([10,5,3,1],["a","c","f","g"])

# %%
different_series2

# %%
different_series + different_series2
