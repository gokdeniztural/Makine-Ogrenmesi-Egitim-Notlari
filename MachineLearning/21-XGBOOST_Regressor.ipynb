# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#https://www.kaggle.com/datasets/camnugent/california-housing-prices/data

# %%
df = pd.read_csv('21-housing.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %% [markdown]
# # DİSTRİBUTİONS GRAFİĞİ OLUŞTURMA

# %%
import math
def plot_all_histogram(df, title_prefix = ""):
    num_cols = df.select_dtypes(include=[np.number]).columns
    n_cols = 3
    n_rows = math.ceil(len(num_cols) / n_cols) # 14/3 --> 4,6 -> 5

    plt.figure(figsize=(5*n_cols, 4*n_rows))

    for i, col in enumerate(num_cols, 1):
        plt.subplot(n_rows, n_cols, i)
        sns.histplot(df[col],kde=True, bins=30)
        plt.title(f"{title_prefix} {col}")
        plt.xlabel("")
        plt.ylabel("")

    plt.tight_layout()
    plt.show()

# %%
plot_all_histogram(df, title_prefix="Original - ")

# %%
df.corr(numeric_only=True)
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# ...

# %% [markdown]
# # Outlier Tespit Fonksiyonu

# %%
def find_outliers_iqr(df, threshold = 1.5):
    outlier_summary = {}
    
    numeric_cols = df.select_dtypes(include = ["float64", "int64"]).columns
    for col in numeric_cols:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1

        lower_bound = Q1 - threshold * IQR
        upper_bound = Q3 + threshold * IQR

        outliers = df[ (df[col] < lower_bound) | (df[col] > upper_bound) ]

        outlier_summary[col] = {
            "outlier_count": outliers.shape[0],
            "outlier_percentage": 100 * outliers.shape[0] / df.shape[0],
            "lower_bound": lower_bound,
            "upper_bound": upper_bound
        }
    return pd.DataFrame(outlier_summary)

# %%
find_outliers_iqr(df)
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# outlier_count           0.000      0.00                 0.0  1287.000000
# outlier_percentage      0.000      0.00                 0.0     6.235465
# lower_bound          -127.485     28.26               -10.5 -1102.625000
# upper_bound          -112.325     43.38                65.5  5698.375000
#
#                     total_bedrooms   population   households  median_income  \
# outlier_count          1271.000000  1196.000000  1220.000000     681.000000
# outlier_percentage        6.157946     5.794574     5.910853       3.299419
# lower_bound            -230.500000  -620.000000  -207.500000      -0.706375
# upper_bound            1173.500000  3132.000000  1092.500000       8.013025
#
#                     median_house_value
# outlier_count              1071.000000
# outlier_percentage            5.188953
# lower_bound              -98087.500000
# upper_bound              482412.500000

# %%
################################################################################
# OUTLIER (AYKIRI DEĞER) TEMİZLEME STRATEJİSİ
################################################################################

# 1. NEDEN SADECE HEDEF SÜTUN (Target Column)?
#  - Hedefimiz olan 'median_house_value' sütunundaki aykırı değerleri sileceğiz.
#  - Çünkü modelin tahmin etmeye çalıştığı şey budur. Hedefteki aşırı uç değerler,
#    Loss Function'ı (Hata Fonksiyonu) saptırabilir ve modelin yanlış öğrenmesine sebep olabilir.

# 2. GİRDİ SÜTUNLARINA (Input Features) NEDEN DOKUNMUYORUZ?
#   - Girdi sütunlarındaki (X) aykırı değerler de normalde modele zarar verebilir.
#   - ANCAK: Biz Karar Ağacı tabanlı modeller (Decision Trees, Random Forest, Gradient Boosting vb.)
#     kullanacağımız için bu modeller aykırı değerlere karşı dayanıklıdır (Robust).
#   - Bu sayede girdi verilerindeki her aykırı değeri silip veri setimizi küçültmek zorunda kalmayacağız.
#   - Veri kaybını minimumda tutarak maksimum bilgiyi korumuş olacağız.

# 3. SONRAKİ ADIM (DENEY):
#   - Yine de emin olmak için iki farklı senaryoyu kıyaslayacağız:
#     a) Tüm veriyi temizlersek ne olur?
#     b) Sadece hedef sütunu temizlersek ne olur?
################################################################################

# %%
def remove_outliers_from_column(df, target_col, threshold = 1.5):
    Q1 = df[target_col].quantile(0.25)
    Q3 = df[target_col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - threshold * IQR
    upper_bound = Q3 + threshold * IQR

    return df[ (df[target_col] >= lower_bound) & (df[target_col] <= upper_bound) ]

# %%
def remove_outliers_from_all_columns(df, threshold = 1.5):
    df_clean = df.copy()
    numeric_cols = df.select_dtypes(include = ["float64", "int64"]).columns
    for col in numeric_cols:
      Q1 = df[col].quantile(0.25)
      Q3 = df[col].quantile(0.75)
      IQR = Q3 - Q1

      lower_bound = Q1 - threshold * IQR
      upper_bound = Q3 + threshold * IQR

      df_clean = df_clean[ (df_clean[col] >= lower_bound) & (df_clean[col] <= upper_bound) ]
    
    return df_clean.copy()

# %%
print("original data shape: ", df.shape)
df_target_clean = remove_outliers_from_column(df, "median_house_value")
print("only target column cleaning shape: ", df_target_clean.shape)
df_all_clean = remove_outliers_from_all_columns(df)
print("all columns cleaning shape: ", df_all_clean.shape)
# Out:
# original data shape:  (20640, 10)
# only target column cleaning shape:  (19569, 10)
# all columns cleaning shape:  (17446, 10)

# %%
# Daha önce bahsettiğim sebeplerden ötürü (ağaç tabanlı modellerin dayanıklı olması vs.), ben bu projede sadece hedef sütundaki (target column)
# aykırı değerleri temizleyerek devam edeceğim.

# Ama eğer merak ediyorsan veya emin olmak istiyorsan; sen diğer yöntemleri de (yani tüm veriyi temizlediğin versiyonu vs.)
# deneyip sonuçları kıyaslayabilirsin.

# %%
df_target_clean.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        200
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df_target_clean.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  19569.000000  19569.000000        19569.000000  19569.000000
# mean    -119.562786     35.654159           28.352752   2619.977260
# std        2.005764      2.151007           12.497772   2183.419302
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.760000     33.930000           18.000000   1438.000000
# 50%     -118.510000     34.270000           28.000000   2110.000000
# 75%     -117.990000     37.730000           37.000000   3123.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    19369.000000  19569.000000  19569.000000   19569.000000
# mean       539.893335   1442.788952    501.394859       3.665568
# std        422.650225   1145.011369    383.396308       1.557927
# min          2.000000      3.000000      2.000000       0.499900
# ...

# %%
df_target_clean["total_bedrooms"] = df_target_clean["total_bedrooms"].fillna(df_target_clean["total_bedrooms"].median())
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_13612\3688706348.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_target_clean["total_bedrooms"] = df_target_clean["total_bedrooms"].fillna(df_target_clean["total_bedrooms"].median())

# %%
df_target_clean.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  19569.000000  19569.000000        19569.000000  19569.000000
# mean    -119.562786     35.654159           28.352752   2619.977260
# std        2.005764      2.151007           12.497772   2183.419302
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.760000     33.930000           18.000000   1438.000000
# 50%     -118.510000     34.270000           28.000000   2110.000000
# 75%     -117.990000     37.730000           37.000000   3123.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    19569.000000  19569.000000  19569.000000   19569.000000
# mean       538.841739   1442.788952    501.394859       3.665568
# std        420.612109   1145.011369    383.396308       1.557927
# min          2.000000      3.000000      2.000000       0.499900
# ...

# %%
df_target_clean.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
df_target_clean["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     8552
# INLAND        6519
# NEAR OCEAN    2419
# NEAR BAY      2074
# ISLAND           5
# Name: count, dtype: int64

# %%
df_target_clean = pd.get_dummies(df_target_clean, columns=["ocean_proximity"], drop_first=True)

# %%
df_target_clean.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  \
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0
#
#    ocean_proximity_INLAND  ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 0                   False                   False                      True
# ...

# %%
X = df_target_clean.drop("median_house_value", axis=1)
y = df_target_clean["median_house_value"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y , test_size=0.3, random_state=15)

# %%
X_train.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity_INLAND', 'ocean_proximity_ISLAND',
#        'ocean_proximity_NEAR BAY', 'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %%
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true,predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Lasso": Lasso(),
    "Ridge": Ridge(),
    "K Neighbors Regressor": KNeighborsRegressor(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest Regressor": RandomForestRegressor(),
    "Adaboost Regressor": AdaBoostRegressor(),
    "GradientBoost Regressor": GradientBoostingRegressor(),
    "XGBoost Regressor":  XGBRegressor()
}

# %%
for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train,y_train)

    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    model_train_mae, model_train_rmse, model_train_r2_square = evaluate_model(y_train, y_train_pred)
    model_test_mae, model_test_rmse, model_test_r2_square = evaluate_model(y_test, y_test_pred)

    print(list(models.keys())[i])
    print("Model Performance for Training Set")
    print("Root Mean Squared Error: ", model_train_rmse)
    print("Mean Absolute Error: ", model_train_mae)
    print("R2 Score: ", model_train_r2_square)

    print("-----------------------------------")
    print("Model Performance for Test Set")
    print("Root Mean Squared Error: ", model_test_rmse)
    print("Mean Absolute Error: ", model_test_mae)
    print("R2 Score: ", model_test_r2_square)

    print("-----------------------------------")
    print("\n")
# Out:
# Linear Regression
# Model Performance for Training Set
# Root Mean Squared Error:  59377.105929262376
# Mean Absolute Error:  43858.38748241092
# R2 Score:  0.6104236470924751
# -----------------------------------
# Model Performance for Test Set
# Root Mean Squared Error:  58769.54725739207
# Mean Absolute Error:  43594.36386300802
# R2 Score:  0.6263296157229532
# -----------------------------------
#
#
# Lasso
# Model Performance for Training Set
# Root Mean Squared Error:  59377.14466856272
# Mean Absolute Error:  43859.00858534639
# R2 Score:  0.6104231387510856
# -----------------------------------
# Model Performance for Test Set
# Root Mean Squared Error:  58768.46230442247
# Mean Absolute Error:  43594.66878006602
# R2 Score:  0.6263434123598096
# -----------------------------------
#
#
# Ridge
# Model Performance for Training Set
# Root Mean Squared Error:  59381.168680071445
# Mean Absolute Error:  43864.6773149373
# R2 Score:  0.6103703334199277
# ...

# %%
from sklearn.preprocessing import PowerTransformer
pt_X = PowerTransformer(method='yeo-johnson')

X_train_transformed = pt_X.fit_transform(X_train)
X_test_transformed = pt_X.transform(X_test)

# %%
column_names = X_train.columns
X_train_transformed_df = pd.DataFrame(X_train_transformed, columns=column_names)

# %%
X_train_transformed_df.head()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0  7.771561e-16 -0.670997            0.486589     0.050535        0.024399
# 1  1.387779e-15 -1.204084           -0.970340     0.432472        0.522800
# 2  1.165734e-15 -0.721609            0.022996     0.305957        0.685602
# 3  8.326673e-16 -0.972150           -0.296774     0.225063        0.655914
# 4 -1.471046e-15  1.423073           -0.056065    -0.548070       -0.448934
#
#    population  households  median_income  ocean_proximity_INLAND  \
# 0    0.358262    0.058133      -0.018646                1.411199
# 1    0.628352    0.363502      -0.940026               -0.708617
# 2    0.800713    0.621156      -0.907275                1.411199
# 3    0.434484    0.557085      -0.254036               -0.708617
# 4   -0.944478   -0.697868      -2.133232                1.411199
#
#    ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 0               -0.014801                 -0.340747
# ...

# %%
plot_all_histogram(X_train_transformed_df, title_prefix='Transformed -')

# %%
plot_all_histogram(df, title_prefix="Original -")

# %%
from scipy.stats import boxcox

y_train_transformed , lambda_y = boxcox(y_train)

# Inverse -> BoxCox
def inverse_boxcox(y, lambda_):
    if lambda_ == 0:
        return np.exp(y)
    else:
        return np.power(y * lambda_ + 1 , 1 / lambda_)

# %%
xgboost_params = {
    "learning_rate": [0.1, 0.01],
    "max_depth": [5,8,12,20,30],
    "n_estimators": [100,200,300,500],
    "colsample_bytree": [0.3,0.4,0.5,0.6,0.7,1]
}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
randomized_cv = RandomizedSearchCV(estimator=XGBRegressor(), param_distributions=xgboost_params, cv=5, n_jobs=-1)

# %%
randomized_cv.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           feature_weights=None, gamma=None,
#                                           grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraint...
#                                           max_delta_step=None, max_depth=None,
# ...

# %%
randomized_cv.best_params_
# Out:
# {'n_estimators': 500,
#  'max_depth': 5,
#  'learning_rate': 0.1,
#  'colsample_bytree': 0.6}

# %%
model_transformed = XGBRegressor(n_estimators = 500, max_depth = 12, learning_rate = 0.1, colsample_bytree = 0.5)

# %%
model_transformed.fit(X_train_transformed, y_train_transformed)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.5, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=12,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=500,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred_transformed = model_transformed.predict(X_test_transformed)

# %%
y_pred_original = inverse_boxcox(y_pred_transformed, lambda_y)

# %%
y_train_pred_transformed = model_transformed.predict(X_train_transformed)
y_train_pred_original = inverse_boxcox(y_train_pred_transformed, lambda_y)


model_train_mae, model_train_rmse, model_train_r2_square = evaluate_model(y_train, y_train_pred_original)
model_test_mae, model_test_rmse, model_test_r2_square = evaluate_model(y_test, y_pred_original)

print(list(models.keys())[i])
print("Model Performance for Training Set")
print("Root Mean Squared Error: ", model_train_rmse)
print("Mean Absolute Error: ", model_train_mae)
print("R2 Score: ", model_train_r2_square)

print("-----------------------------------")
print("Model Performance for Test Set")
print("Root Mean Squared Error: ", model_test_rmse)
print("Mean Absolute Error: ", model_test_mae)
print("R2 Score: ", model_test_r2_square)

print("-----------------------------------")
print("\n")
# Out:
# XGBoost Regressor
# Model Performance for Training Set
# Root Mean Squared Error:  327.9746099591445
# Mean Absolute Error:  191.29365968708527
# R2 Score:  0.9999881140203059
# -----------------------------------
# Model Performance for Test Set
# Root Mean Squared Error:  44900.509517602804
# Mean Absolute Error:  30029.851162708488
# R2 Score:  0.7818845009890262
# -----------------------------------

# %%
'''
We applied the Yeo-Johnson transformation to normalize the numerical features.
However, tree-based models like XGBoost are robust to skewed data. Consequently,
the transformation did not improve the model's performance. In fact, the R2 score dropped from 0.81 to 0.78.
'''
# Out:
# "\nWe applied the Yeo-Johnson transformation to normalize the numerical features.\nHowever, tree-based models like XGBoost are robust to skewed data. Consequently,\nthe transformation did not improve the model's performance. In fact, the R2 score dropped from 0.81 to 0.78.\n"
