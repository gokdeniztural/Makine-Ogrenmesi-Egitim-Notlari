# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
10 in [10,20,30]
# Out:
# True

# %%
5 not in [10,20,30]
# Out:
# True

# %%
myDictionary = {"a":10,"b":20}

# %%
10 in myDictionary.values()
# Out:
# True

# %%
"b" in myDictionary.keys()
# Out:
# True

# %%
myAge = 20

# %%
if myAge < 18:
    print("Çocuksunuz!")
if myAge >= 18:
    print("Yetişkinsiniz!")
# Out:
# Yetişkinsiniz!

# %%
myList = [10,20,30,40,50]

# %%
if 20 in myList:
    print("20 sayisi liste içinde")
else:
    print("20 sayisi liste içinde değil!")
# Out:
# 20 sayisi liste içinde
