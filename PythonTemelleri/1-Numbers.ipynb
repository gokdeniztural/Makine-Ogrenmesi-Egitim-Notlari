# %%
3+8
# Out:
# 11

# %%
4*3
# Out:
# 12

# %%
age=50

# %%
age/2
# Out:
# 25.0

# %%
myName = "Gökdeniz Tural"
myAge = 20

# %%
print(myName)
print(myAge/2)
# Out:
# Gökdeniz Tural
# 10.0

# %%
# data type

# %%
type(myAge*3)
# Out:
# int

# %%
type(3.14)
# Out:
# float

# %%
myFloat = 7.2313213

# %%
type(30/3)
# Out:
# float

# %%
2**5
# Out:
# 32

# %%
2**11
# Out:
# 2048

# %%
10%3
# Out:
# 1
