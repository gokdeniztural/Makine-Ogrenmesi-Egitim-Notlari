# %%
myList = [10,20,"a","b",3.14]

# %%
myList[0] = 100

# %%
myList
# Out:
# [100, 20, 'a', 'b', 3.14]

# %%
# Tuple

# %%
myTuple = (10,20,"a","b",3.14)

# %%
type(myTuple)
# Out:
# tuple

# %%
#myTuple[0] = 100

# %%
#immutability

# %%
myTuple
# Out:
# (10, 20, 'a', 'b', 3.14)

# %%
myTuple.index("a")
# Out:
# 2

# %%
myTuple.count("a")
# Out:
# 1

# %%
myTuple
# Out:
# (10, 20, 'a', 'b', 3.14)

# %%
myTuple = list(myTuple)

# %%
myTuple
# Out:
# [10, 20, 'a', 'b', 3.14]

# %%
# tuple liste oldu
