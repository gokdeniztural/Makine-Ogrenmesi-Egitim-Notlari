# %%
# %%writefile myfile.txt
# test 1
# test 2
# test 3
# Out:
# Writing myfile.txt

# %%
myFile = open("myfile.txt")

# %%
type(myFile)
# Out:
# _io.TextIOWrapper

# %%
myFile.read()
# Out:
# ''

# %%
myFile.read() # Bir kere okudu sonra yazı yazmayan satıra geldi okuyacak her hangi bir metin yok!
# Out:
# ''

# %%
myFile.seek(0) # Dosyanın en başına gidiyoruz.
# Out:
# 0

# %%
myFile.read()
# Out:
# 'test 1\ntest 2\ntest 3\n'

# %%
myFile.close()

# %%
with open("myfile.txt") as myFile:
    myContent = myFile.read()

# %%
myContent
# Out:
# 'test 1\ntest 2\ntest 3\n'

# %%
myContent
# Out:
# 'test 1\ntest 2\ntest 3\n'

# %%
with open("myfile.txt",mode="w") as myNewFile:
    myNewFile.write("test")

# %%
with open("myfile.txt",mode="r") as newFile2:
    myContent = newFile2.read()

# %%
myContent
# Out:
# 'test 4'

# %% [markdown]
# # w --> write , r --> read , a --> append

# %%
with open("myfile.txt",mode="a") as myNewFile3:
    myNewFile3.write("test 5")

# %%
with open("myfile.txt",mode="r") as newFile4:
    myContent = newFile4.read()

# %%
myContent
# Out:
# 'test 4test 5'
