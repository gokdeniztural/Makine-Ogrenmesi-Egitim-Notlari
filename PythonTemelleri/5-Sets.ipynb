# %% [markdown]
# Sets

# %%
# unique elements , unordered

# %%
myList = [10,20,30,40,10,20,10,50,90,10]

# %%
mySet = set(myList)

# %%
mySet
# Out:
# {10, 20, 30, 40, 50, 90}

# %%
mySet = {10,20,30,10,20,30,10,20,30,10,20,30,40,50,60}

# %%
mySet
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
# Yani anlayacağımız 'set'  kaç tane aynı elemandan olduğuyla ilgilenmez.

# %%
mySet2 = {50,60,70,80,90}

# %%
mySet.union(mySet2)
# union() ---> iki set'i birleştirir!
# Out:
# {10, 20, 30, 40, 50, 60, 70, 80, 90}

# %%
mySet.intersection(mySet2)
# intersection kesişimlerini buluyor.
# Out:
# {50, 60}

# %%
emptyList = []

# %%
len(emptyList)
# Out:
# 0

# %%
emptyList = list()    # bu şekilde de oluşturulabilir

# %%
len(emptyList)
# Out:
# 0

# %%
emptyDict = {}  # bu şekilde boş süslü parantez boş dictionary oluşturur set oluşturmaz. Seti 2. yolla oluştururuz aşağıda mevcut.

# %%
len(emptyDict)
# Out:
# 0

# %%
emptyDict["a"]=10
emptyDict["b"]=20
emptyDict
# Out:
# {'a': 10, 'b': 20}

# %%
emptySet = set()

# %%
len(emptySet)
# Out:
# 0

# %%
emptySet.add(10)
emptySet.add(20)
emptySet.add(30)
emptySet.add(10)
emptySet.add(10)

# %%
emptySet
# Out:
# {10, 20, 30}
