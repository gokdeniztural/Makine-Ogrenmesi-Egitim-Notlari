# %% [markdown]
# # DİCTİONARY

# %%
# Key - value pairing

# %%
fruit_list = ["banana","apple"]

# %%
calorie_list = [100,50]

# %%
fruit_list[0]
# Out:
# 'banana'

# %%
calorie_list[0]
# Out:
# 100

# %%
fitness_dictionary = {"banana":100 , "apple":50}

# %%
fitness_dictionary["banana"]
# Out:
# 100

# %%
fitness_dictionary["apple"]
# Out:
# 50

# %%
type(fitness_dictionary)
# Out:
# dict

# %%
fitness_dictionary.keys()
# Out:
# dict_keys(['banana', 'apple'])

# %%
fitness_dictionary.values()
# Out:
# dict_values([100, 50])

# %%
type(fitness_dictionary.values())
# Out:
# dict_values

# %%
list(fitness_dictionary.values())
# veri tipini list'e çevirdik tıpkı int str gibi türlere çevirmek gibi!
# Out:
# [100, 50]

# %%
fitness_dictionary["banana"] = 200

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 50}

# %%
fitness_dictionary["melon"] = 300
# sözlüğe yeni elemanı bu şekilde ekledik. Ekleme metodu bulunmuyor listelerdeki gibi.

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 50, 'melon': 300}

# %%
help(fitness_dictionary.get)
# Out:
# Help on built-in function get:
#
# get(key, default=None, /) method of builtins.dict instance
#     Return the value for key if key is in the dictionary, else default.

# %%
fitness_dictionary.get("apple",0)
# Out:
# 50

# %%
fitness_dictionary.get("aple",0)
# anahtar kelimeyi yanlış girdiğimizde uygulamada hata almamak adına default değer atıyoruz. Görüldüğü üzere aple yazılmış.
# Out:
# 0

# %%
my_dictionary = {"name":"Gökdeniz", "surname": "tural"}

# %%
my_dictionary
# Out:
# {'name': 'Gökdeniz', 'surname': 'tural'}

# %%
my_dictionary["age"] = 20

# %%
my_dictionary
# Out:
# {'name': 'Gökdeniz', 'surname': 'tural', 'age': 20}

# %%
my_mixed_dictionar = {"key1":100,"key2":3.14,"key3":[10,20,30]}
# tek satırd kodda key3 anahtar kelimesinin değeri olan listedeki 20 elemanını nasıl alırız?

# %%
my_mixed_dictionar["key3"][1]
# Out:
# 20

# %%
last_dictionary = {"k1":10,"k2":[10,20,30,40,50],"k3":"string","k4":{"a":100,"b":200}}
# tek satır kodda 200 değerini almaya çalışalım.

# %%
last_dictionary["k4"]["b"]
# Out:
# 200

# %%
last_dictionary["k2"][3]
# Out:
# 40
