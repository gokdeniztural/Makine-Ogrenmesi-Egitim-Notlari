# %%
print("Hellow world")
# Out:
# Hellow world

# %%
name = "gökdeniz"

# %%
type(name)
# Out:
# str

# %%
name.capitalize()
# Out:
# 'Gökdeniz'

# %%
help(name.capitalize)
# Out:
# Help on built-in function capitalize:
#
# capitalize() method of builtins.str instance
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.

# %%
name.upper()
# Out:
# 'GÖKDENIZ'

# %%
name = name.upper()

# %%
name
# Out:
# 'GÖKDENIZ'

# %%
len(name)
# Out:
# 8

# %%
print("Gökdeniz \nTural")
# Out:
# Gökdeniz
# Tural

# %%
# \n --> new line

# %%
print("Gökdeniz \tTural")
# Out:
# Gökdeniz 	Tural

# %% [markdown]
# # INDEX

# %%
myString = "Hello python"

# %%
myString[3]
# Out:
# 'l'

# %%
myString[5]
# Out:
# ' '

# %%
myString[len(myString)-1]
# Out:
# 'n'

# %%
myString[-1]
# Out:
# 'n'

# %%
myString[-2]
# Out:
# 'o'

# %%
name="Gökdeniz"
surName="Tural"
fullName=name + " " + surName

# %%
fullName
# Out:
# 'Gökdeniz Tural'

# %%
fullName*5
# Out:
# 'Gökdeniz TuralGökdeniz TuralGökdeniz TuralGökdeniz TuralGökdeniz Tural'

# %%
# slicing , starting index , stopping index , stepping size

# %%
barcode = "ABCDE12345678"

# %%
barcode
# Out:
# 'ABCDE12345678'

# %%
#barcode[#starting index:#stopping index:#stepping size]

# %%
barcode[0:5:1]
# Out:
# 'ABCDE'

# %%
barcode[3:8:1]
# Out:
# 'DE123'

# %%
fullName.index("T")
# Out:
# 9

# %%
fullName.split()
# Out:
# ['Gökdeniz', 'Tural']

# %%
type(fullName.split())
# Out:
# list
