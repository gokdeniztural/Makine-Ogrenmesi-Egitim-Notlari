# %%
name : str = "Gökdeniz"
age : int = 21
is_student : bool = False

# Kodun okunabilirliğini artırır! Kullanımı zorunlu değil

# %%
type(name)
# Out:
# str

# %%
def add_number(a: int , b: int) -> int:
    return a + b

# type'ları belirtmesek de çalışır ama kodun okunabilirliği artar bu şekilde. -> Return edecek değerin tipini belirtir.

# %%
add_number(4,5)
# Out:
# 9

# %%
def process_value(value: int | str) -> str:
    if isinstance(value,int):
        return f"processed integer: {value}"
    else:
        return f"processed string: {value}"

# %%
process_value(50)
# Out:
# 'processed integer: 50'

# %%
process_value("Hello")
# Out:
# 'processed string: Hello'

# %%
process_value([10,20,30])
# else dediğim için listeyi de string algılayacak!
# Out:
# 'processed string: [10, 20, 30]'

# %%
# python 3.9
from typing import List

def sumList(numbers: List[int]) -> int:
    return sum(numbers)

# %%
numbers =  [1,2,3,4]

# %%
sumList(numbers)
# Out:
# 10
