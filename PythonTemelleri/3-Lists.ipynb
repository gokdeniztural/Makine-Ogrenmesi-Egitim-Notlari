# %%
myString = "Hello Python"

# %%
#myString[0] = "A"

# %%
#immutable - immutabilty
# myString'in tek bir elemanını değiştiremeyiz!!!

# %% [markdown]
# # Lists

# %%
myList = [10,20,30]

# %%
type(myList)
# Out:
# list

# %%
x = 10
y = 20
z = 30

# %%
myList = [x,y,z]

# %%
myList
# Out:
# [10, 20, 30]

# %%
myList = [10,20,30,40]

# %%
myList[0] = 90

# %%
myList
# Out:
# [90, 20, 30, 40]

# %%
#mutable - mutability

# %%
myList.append(80)

# %%
myList
# Out:
# [90, 20, 30, 40, 80]

# %%
#myList.clear()
# Listeyi siliyor!

# %%
myList
# Out:
# [10, 20, 30, 40, 80]

# %%
len(myList)
# Out:
# 5

# %%
myList.count(10)
# Listenin içinde kaç tane 10 varsa onu yazar!
# Out:
# 1

# %%
myList.insert(2,99)
# 2. indexe 99 u ekler diğer elemanları bir sağa kaydırır.

# %%
myList
# Out:
# [10, 20, 99, 30, 40, 80]

# %%
myList.pop()
# son elemanı listeden atar!
# Out:
# 40

# %%
myList
# Out:
# [10, 20, 99, 99, 30, 40]

# %%
myList.insert(4,99)

# %%
myList
# Out:
# [10, 20, 99, 99, 99, 30]

# %%
myList.remove(99)

# %%
myList
# Out:
# [10, 20, 99, 99, 30]

# %%
myList.remove(99)

# %%
myList
# Out:
# [10, 20, 99, 30]

# %%
myList.reverse()
# Listeyi tersine çevirir!

# %%
myList
# Out:
# [30, 99, 20, 10]

# %%
myList.sort()

# %%
myList = [10,20,30,40,50]

# %%
myList
# Out:
# [10, 20, 30, 40, 50]

# %%
myList
# Out:
# [10, 20, 30, 40, 50]

# %%
List1 = [10,20,30]
List2 = [40,50,60]

# %%
List1+List2
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
mixedList = ["Ali",20,3.14]
type(mixedList)
# Out:
# list

# %%
List1 * 2
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
myNestedList = [10,20,30,40,[90,180,270]]
# NESTED LİST

# %%
myNestedList[0]
# Out:
# 10

# %%
myNestedList[4]
# Out:
# [90, 180, 270]

# %%
smallList = myNestedList[4]

# %%
smallList
# Out:
# [90, 180, 270]

# %%
type(smallList)
# Out:
# list

# %%
myNestedList[4][1]  # Nested Listin içindeki listenin bir elemanını böyle alırız!
# Out:
# 180
